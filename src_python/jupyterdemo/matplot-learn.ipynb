# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
np.random.seed(19680801)
data = np.random.randn(2, 100)

# %%
data.shape
# Out:
# (2, 100)

# %%
print(data)
# Out:
# [[ 1.04930431e+00  8.66099175e-01  5.51134600e-01  1.72807779e+00
#   -6.49288117e-01 -4.78419576e-01  1.07788511e+00  9.68810333e-01
#   -8.09344793e-01 -1.23738910e+00  1.86011654e+00 -3.08319237e-01
#    7.82970551e-01  2.15234472e-02  7.15663788e-01  1.40146651e+00
#   -1.12750212e+00  1.65581822e+00  1.40096148e+00  2.01990070e-01
#   -9.64863564e-01  1.04458851e+00 -4.31050687e-01 -4.97319497e-01
#   -5.91174157e-02 -1.11460467e+00 -1.22699779e+00 -1.41008819e+00
#    1.31086051e+00 -5.17442074e-01 -1.66581368e-02  4.69172251e-01
#    7.76778095e-01 -1.88469769e+00 -1.27587333e-01 -5.19317436e-01
#    7.35143220e-01  1.34685132e+00  5.50255053e-01 -2.29051158e-01
#    6.61231626e-01 -5.36368467e-01 -4.81944376e-01  3.12723563e-01
#   -3.12183853e+00 -1.35847701e+00 -1.42638207e-01 -2.16996926e-01
#   -3.28680039e-02  1.83214468e+00  3.52359841e-01  2.36645133e-01
#    1.47854807e+00  1.55430657e+00 -1.11060898e+00  8.23788563e-01
#    6.65274688e-01  7.14766390e-01 -1.23078705e+00  2.09540213e+00
#   -6.03219482e-01  1.61355306e+00 -2.53984050e-01 -1.51587877e+00
#   -1.17226523e-01  4.95428359e-01 -7.02590848e-01  3.95069536e-01
#   -1.12327902e+00 -1.71555479e+00 -2.71105146e-01  8.62407388e-02
#   -1.09047119e+00  1.12543013e-01 -9.53644467e-01  5.02231944e-02
#   -4.83160602e-01  1.33390330e+00  4.80188080e-01 -7.49726660e-01
#   -1.32077656e+00  3.32231600e-01 -2.66608341e-01  6.36202025e-01
#   -1.11831517e+00  2.64545151e-01  9.30594129e-02 -1.19619809e+00
#   -8.98927800e-01 -4.53967205e-02 -5.97167582e-01  1.56191529e-02
#   -6.07183913e-01  7.21400830e-01  4.64277678e-01  8.26559419e-01
#    9.30120332e-02 -2.26228309e+00  9.90723646e-01 -1.27381576e+00]
#  [-1.38773694e+00  1.55220778e-01  7.36724806e-02  1.02914804e+00
#   -6.60381555e-01 -6.18870616e-01 -1.89537050e-01 -5.46035071e-01
#    1.62580496e+00 -1.02545765e-01 -1.43000396e+00  8.75383010e-01
#   -1.51739235e-01 -3.69969132e-01  1.39836228e-02 -8.16679839e-02
#    1.09247734e+00  5.27782523e-01  1.74167749e+00 -5.46324477e-01
#    1.65736795e+00  6.73629965e-01 -8.48480008e-02 -1.65240435e+00
#    6.43563731e-01 -9.14329030e-01  3.49878342e-01  9.80876233e-02
#    9.20133074e-01  4.16248081e-01  6.88298652e-01 -3.27091982e-02
#    5.42544505e-01 -5.88782966e-03 -1.36174511e+00 -3.17451269e-01
#   -2.32676449e+00  8.79554336e-01 -6.85958787e-01 -1.19423245e+00
#   -1.22019276e+00 -8.51083359e-01  6.73740039e-01  6.35835705e-01
#    8.35274905e-01  1.81992918e-01  1.23229074e+00 -9.96841814e-01
#   -8.04237843e-01  1.83322987e+00  8.40462099e-02 -4.66226311e-01
#   -4.58791439e-01 -6.23694657e-01  6.45132873e-01 -1.85158063e+00
#    8.43342331e-01  1.09386676e+00  4.56575777e-01  2.73130831e-01
#   -1.91682051e+00  1.62999085e-01  9.20437057e-01 -6.67275456e-01
#   -4.66619092e-02 -6.13770999e-01 -3.74933938e-01  5.16940818e-01
#    5.38914484e-01  1.52495903e-03 -1.07786263e-01  6.90346916e-01
#    1.48077994e+00  9.05456081e-01  1.63013950e+00  5.30195841e-02
#   -1.67786677e+00 -3.06046411e-01 -1.61530935e-01  1.12748366e+00
#   -2.78086673e-02  2.90107302e-02 -8.38883358e-01 -9.97609243e-01
#    1.96853367e-01 -1.56702295e+00  7.68129015e-02  2.29493807e-01
#    1.16447260e+00  1.35605750e-02 -1.13170017e+00 -6.98519887e-01
#   -1.28332743e+00 -1.03435213e+00  8.58721686e-01 -1.12860543e+00
#    4.25096719e-01  1.01614134e+00 -3.13862515e+00 -4.92030627e-01]]

# %%
fig, axs = plt.subplots(2, 2, figsize=(5, 5))
axs[0, 0].hist(data[0])
axs[1, 0].scatter(data[0], data[1])
axs[0, 1].plot(data[0], data[1])
axs[1, 1].hist2d(data[0], data[1])
plt.show()

# %%
plt.style.use('ggplot')
fig, axs = plt.subplots(2, 2, figsize=(5, 5))
axs[0, 0].hist(data[0])
axs[1, 0].scatter(data[0], data[1])
axs[0, 1].plot(data[0], data[1])
axs[1, 1].hist2d(data[0], data[1])
plt.show()

# %%
print(plt.style.available)
# Out:
# ['seaborn-dark', 'seaborn-darkgrid', 'seaborn-ticks', 'fivethirtyeight', 'seaborn-whitegrid', 'classic', '_classic_test', 'fast', 'seaborn-talk', 'seaborn-dark-palette', 'seaborn-bright', 'seaborn-pastel', 'grayscale', 'seaborn-notebook', 'ggplot', 'seaborn-colorblind', 'seaborn-muted', 'seaborn', 'Solarize_Light2', 'seaborn-paper', 'bmh', 'tableau-colorblind10', 'seaborn-white', 'dark_background', 'seaborn-poster', 'seaborn-deep']

# %%
with plt.style.context(('dark_background')):
    plt.plot(np.sin(np.linspace(0, 2 * np.pi)), 'r-o')
plt.show()

# %%
fig = plt.figure() # an empty figure with no axes
fig.suptitle('No axes on this figure') # Add a title so we know which it is
fig, ax_lst = plt.subplots(2, 2) # a figure with a 2x2 grid of Axes
