# %%
import pandas as pd
#import pymysql as pm
from sqlalchemy import create_engine

# %%
conn = create_engine('mysql+pymysql://root:passw0rd@mysqlserver2:3306/ai')

# %%
rst = conn.execute('select count(1) from xinfadi')

# %%
for one in rst.fetchall():
    print(one)
# Out:
# (304369,)

# %%
#df = pd.read_sql('select * from xinfadi where mingcheng="大白菜" and guige=".冀"',conn)
#df = pd.read_sql('select * from xinfadi where mingcheng="大白菜" and guige="冀储存_鲁新"',conn)
df = pd.read_sql('select * from xinfadi where mingcheng="大白菜"',conn)
rdf = pd.read_sql('select * from xinfadi where mingcheng="纯瘦肉"',conn)

# %%
guiges =df["guige"].unique()
rguiges=rdf['guige'].unique()

# %%
rguiges
# Out:
# array(['普通'], dtype=object)

# %%
for idx,oneguige in enumerate(guiges):
    tmp = df[df['guige'].isin([oneguige])]
    exec("rdf%s=tmp"%idx)
print(idx)

for idx,roneguige in enumerate(rguiges):
    rtmp = rdf[rdf['guige'].isin([roneguige])]
    exec("rdf%s=tmp"%idx)
print(idx)
# Out:
# 17
# 0

# %%
df18
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-38-912be5fce05a> in <module>
# ----> 1 df18
#
# NameError: name 'df18' is not defined

# %%
odf=df.sort_values(by="riqi",ascending= True) 
print(odf)
# Out:
#     mingcheng  zuidi  pingjun  zuigao guige danwei        riqi      id
# 911       大白菜   0.20     0.28    0.35    普通      斤  2019-01-01  303592
# 909       大白菜   0.20     0.28    0.35    普通      斤  2019-01-02  302594
# 907       大白菜   0.20     0.26    0.32    普通      斤  2019-01-03  302015
# 906       大白菜   0.22     0.28    0.35    普通      斤  2019-01-04  301434
# 905       大白菜   0.22     0.28    0.35    普通      斤  2019-01-05  300920
# ..        ...    ...      ...     ...   ...    ...         ...     ...
# 1         大白菜   0.40     0.50    0.60  储存.新      斤  2021-04-02     556
# 2         大白菜   0.40     0.50    0.60  储存.新      斤  2021-04-03     688
# 0         大白菜   0.40     0.50    0.60  储存.新      斤  2021-04-04      21
# 914       大白菜   0.40     0.50    0.60  储存.新      斤  2021-04-04  304112
# 913       大白菜   0.40     0.50    0.60  储存.新      斤  2021-04-05  304071
#
# [915 rows x 8 columns]

# %%
print(guiges)
# Out:
# ['储存.新' '存储' '新' '储存_新.黄心' '_黄心' '黑_冀津' '黑_冀' '冀_' '冀储存_鲁新' '.冀豫' '.冀'
#  '黄心' '精品' '黄心大头青口' '.冀新' '鲁新.冀存' '.冀存' '普通']

# %%
odf4=df4.sort_values(by="riqi",ascending= True)
odf8=df8.sort_values(by="riqi",ascending= True)
odf10=df10.sort_values(by="riqi",ascending= True)
ordf = rdf.sort_values(by="riqi",ascending= True)

# %%
import matplotlib.pyplot as plt
import random
#df4,df8,df10
x4= odf4["riqi"]
y4= odf4["pingjun"]

x8= odf8["riqi"]
y8= odf8["pingjun"]

x10= odf10["riqi"]
y10= odf10["pingjun"]


plt.figure(figsize=(10,6),dpi=100)
plt.plot(x4,y4,label=guiges[4].replace("_","u"))
plt.plot(x8,y8,label=guiges[8],color="g")
plt.plot(x10,y10,label=guiges[10],color="y")

plt.legend(loc=0)
plt.title('大白菜',fontsize=20)
plt.show()

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
rx= ordf["riqi"]
ry= ordf["pingjun"]


ryzuigao= ordf["zuigao"]
ryzuidi= ordf["zuidi"]

plt.figure(figsize=(10,6),dpi=100)


plt.plot(rx,ry,label='平均',color="b")
# plt.plot(rx,ryzuigao,label='最高',color="r")
# plt.plot(rx,ryzuidi,label='最低',color="g")
plt.legend(loc=0)
plt.title('纯瘦肉',fontsize=20)

plt.show()

# %%
data={'state':[1,1,2,2,1,2,2],'pop':['a','b','c','d','b','c','d']}
frame=pd.DataFrame(data)

# %%
frame
# Out:
#    state pop
# 0      1   a
# 1      1   b
# 2      2   c
# 3      2   d
# 4      1   b
# 5      2   c
# 6      2   d

# %%
df = frame.drop_duplicates(subset=['pop','state'])

# %%
df
# Out:
#    state pop
# 0      1   a
# 1      1   b
# 2      2   c
# 3      2   d

# %%
# from pylab import mpl
# # 设置显示中文字体
# mpl.rcParams["font.sans-serif"] = ["SimHei"]

# %%
from matplotlib.font_manager import FontManager
import subprocess
 
mpl_fonts = set(f.name for f in FontManager().ttflist)
 
print('all font list get from matplotlib.font_manager:')
for f in sorted(mpl_fonts):
    print('t' + f)
# Out:
# all font list get from matplotlib.font_manager:
# tDejaVu Sans
# tDejaVu Sans Display
# tDejaVu Sans Mono
# tDejaVu Serif
# tDejaVu Serif Display
# tSTIXGeneral
# tSTIXNonUnicode
# tSTIXSizeFiveSym
# tSTIXSizeFourSym
# tSTIXSizeOneSym
# tSTIXSizeThreeSym
# tSTIXSizeTwoSym
# tcmb10
# tcmex10
# tcmmi10
# tcmr10
# tcmss10
# tcmsy10
# tcmtt10

# %%
import matplotlib
matplotlib.rcParams['font.sans-serif']=['SimHei']    #指定默认字体 SimHei为黑体
matplotlib.rcParams['axes.unicode_minus']=False   #用来正常显示负号

# %%
import matplotlib
print(matplotlib.matplotlib_fname())
# Out:
# /opt/conda/lib/python3.8/site-packages/matplotlib/mpl-data/matplotlibrc

# %%
import matplotlib.pyplot as plt
import random
plt.rcParams['font.sans-serif']=['SimHei']    #指定默认字体 SimHei为黑体
plt.rcParams['axes.unicode_minus']=False   #用来正常显示负号

# 准备数据
x=range(60)
y_shanghai=[random.uniform(15,18) for i in x]
#创建北京温度数据
y_beijing=[random.uniform(1,3) for i in x]

# 生成x刻度标签
x_ticklabels=["11点{}".format(i) for i in x]
# 生成y标签
y_ticklabels=range(40)

# 1.创建画布
plt.figure(figsize=(10,6),dpi=100)
# 2.绘制图像
# plt.plot(x,y_shanghai)#上海 No handles with labels found to put in legend.
plt.plot(x,y_shanghai,label="上海")
plt.plot(x,y_beijing,label="北京",linestyle="--",color="g") #绘制北京的
# 2.1添加刻度标签
# plt.xticks(x_ticklabels[::5]) 报错  'NoneType' object has no attribute 'update'
plt.xticks(x[::5],x_ticklabels[::5],fontsize=10)
plt.yticks(y_ticklabels[::5])
#2.2添加网格
plt.grid(True,linestyle="--",alpha=0.5)
#2.3添加标题-描述信息
plt.xlabel('时间',fontsize=16)
plt.ylabel('温度',fontsize=16)
plt.title('上海市一小时温度变化',fontsize=20)
#2.4添加图例
plt.legend(loc=0)

#图片保存
plt.savefig("./test.png") #保存图像一定要在show之前

# 3.显示图像
plt.show()
